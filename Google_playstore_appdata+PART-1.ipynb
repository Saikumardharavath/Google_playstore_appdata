# %%
#1. Import required libraries and read the dataset.

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/Apps_data+(1).csv')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
#2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
data.tail(5)
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data.describe().T
# Out:
#          count      mean       std  min  25%  50%  75%   max
# Rating  9367.0  4.193338  0.537431  1.0  4.0  4.3  4.5  19.0

# %%
#3. Check summary statistics of the dataset. List out the columns that need to be worked upon for model building.

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
#          Type  Price Content Rating Genres    Last Updated  \
# count   10840  10841          10840  10841           10841
# unique      3     93              6    120            1378
# top      Free      0       Everyone  Tools  August 3, 2018
# freq    10039  10040           8714    842             326
# mean      NaN    NaN            NaN    NaN             NaN
# std       NaN    NaN            NaN    NaN             NaN
# min       NaN    NaN            NaN    NaN             NaN
# 25%       NaN    NaN            NaN    NaN             NaN
# 50%       NaN    NaN            NaN    NaN             NaN
# 75%       NaN    NaN            NaN    NaN             NaN
# max       NaN    NaN            NaN    NaN             NaN
#
#                Current Ver Android Ver
# count                10833       10838
# unique                2832          33
# top     Varies with device  4.1 and up
# freq                  1459        2451
# mean                   NaN         NaN
# std                    NaN         NaN
# min                    NaN         NaN
# 25%                    NaN         NaN
# 50%                    NaN         NaN
# 75%                    NaN         NaN
# max                    NaN         NaN

# %%
data['Rating'].mode()
# Out:
# 0    4.4
# Name: Rating, dtype: float64

# %%
data['Rating'].median()
# Out:
# 4.3

# %%
data['Rating'].fillna(data['Rating'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
#4. Check if there are any duplicate records in the dataset? if any drop them.

# %%
duplicates= data[data.duplicated()]

# %%
duplicates
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 229      80805  Varies with device    5,000,000+  Free     0       Everyone
# 236     159872  Varies with device   10,000,000+  Free     0       Everyone
# 239      70991  Varies with device    5,000,000+  Free     0       Everyone
# 256      31614                 37M   10,000,000+  Free     0       Everyone
# 261       6989  Varies with device    1,000,000+  Free     0       Everyone
# ...        ...                 ...           ...   ...   ...            ...
# 8643    404610  Varies with device   10,000,000+  Free     0       Everyone
# 8654     25370  Varies with device    1,000,000+  Free     0       Everyone
# 8658   2401017  Varies with device  100,000,000+  Free     0       Everyone
# 10049      123                 86M       10,000+  Free     0       Everyone
# 10768       63                 24M       10,000+  Free     0       Everyone
#
#              Genres       Last Updated         Current Ver         Android Ver
# 229        Business  February 26, 2018  Varies with device        4.0.3 and up
# 236        Business      July 31, 2018  Varies with device  Varies with device
# 239        Business      July 24, 2018    2.19.0.204537701          4.4 and up
# 256        Business      July 20, 2018      4.1.28165.0716          4.0 and up
# 261        Business      July 16, 2018           4.3.0.508          4.4 and up
# ...             ...                ...                 ...                 ...
# 8643   Productivity      April 6, 2018  Varies with device  Varies with device
# 8654   Productivity     August 6, 2018  Varies with device  Varies with device
# 8658   Productivity      June 27, 2018  Varies with device  Varies with device
# 10049       Medical       June 1, 2018              0.6.88          5.0 and up
# 10768       Medical      June 22, 2018               2.3.1          5.0 and up
#
# [483 rows x 13 columns]

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
data.shape
# Out:
# (10358, 13)

# %%
data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#5. Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them.

# %%
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
invalid=data[data['Category']=='1.9']

# %%
invalid
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data.drop(10472,inplace=True)

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     4.3       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10357 rows x 13 columns]

# %%
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
import numpy as np

# %%
#6. Check if there are missing values present in the column Rating, If acreate a new column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)ny? drop them and and

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     4.3       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10357 rows x 13 columns]

# %%
data['Rating'].isnull().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (10357, 13)

# %%
data['Rating_category'] = np.where(data['Rating']>3.5, 'high', 'low')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     4.3       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver Rating_category
# 0                   1.0.0        4.0.3 and up            high
# 1                   2.0.0        4.0.3 and up            high
# 2                   1.2.4        4.0.3 and up            high
# 3      Varies with device          4.2 and up            high
# 4                     1.1          4.4 and up            high
# ...                   ...                 ...             ...
# 10836                1.48          4.1 and up            high
# 10837                 1.0          4.1 and up            high
# 10838                 1.0          2.2 and up            high
# 10839  Varies with device  Varies with device            high
# 10840  Varies with device  Varies with device            high
#
# [10357 rows x 14 columns]

# %%
#7. Check the distribution of the newly created column 'Rating_category' and comment on the distribution.

# %%
dist=data['Rating_category'].value_counts()

# %%
dist
# Out:
# high    9477
# low      880
# Name: Rating_category, dtype: int64

# %%
data['Rating_category'].hist()
# Out:
# <Axes: >

# %%
#8. Convert the column "Reviews'' to numeric data type and check the presence of outliers in the column and handle the outliers using a transformation approach.(Hint: Use log transformation)

# %%
data['Reviews']=pd.to_numeric(data['Reviews'])

# %%
data.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size                object
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data[['Reviews']]
# Out:
#        Reviews
# 0          159
# 1          967
# 2        87510
# 3       215644
# 4          967
# ...        ...
# 10836       38
# 10837        4
# 10838        3
# 10839      114
# 10840   398307
#
# [10357 rows x 1 columns]

# %%
plt.boxplot(data['Reviews'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b23ceb5aa10>,
#   <matplotlib.lines.Line2D at 0x7b23ceb5acb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b23ceb5af50>,
#   <matplotlib.lines.Line2D at 0x7b23ceb5b1f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b23ceb5a770>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b23ceb5b490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b23ceb5b730>],
#  'means': []}

# %%
np.log(data['Reviews'])
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0         5.068904
# 1         6.874198
# 2        11.379508
# 3        12.281384
# 4         6.874198
#            ...
# 10836     3.637586
# 10837     1.386294
# 10838     1.098612
# 10839     4.736198
# 10840    12.894978
# Name: Reviews, Length: 10357, dtype: float64

# %%
plt.boxplot(np.log(data['Reviews']))
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b23ce9cfa30>,
#   <matplotlib.lines.Line2D at 0x7b23ce9cfcd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b23ce9cff70>,
#   <matplotlib.lines.Line2D at 0x7b23cea08250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b23ce9cf790>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b23ce9cce80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b23ceb5bb80>],
#  'means': []}

# %%
#9. The column 'Size' contains alphanumeric values, treat the non numeric data and convert the column into suitable data type. (hint: Replace M with 1 million and K with 1 thousand, and drop the entries where size='Varies with device')

# %%
data['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10357, dtype: object

# %%
data['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %%
data['Size'] = data['Size'].apply(lambda x:x.replace(',',''))

# %%
data['Size'] = data['Size'].str.replace('M','000000')

# %%
data['Size'] = data['Size'].str.replace('k','000')

# %%
Varies_with_device=data[data["Size"] == "Varies with device"].index

# %%
Varies_with_device
# Out:
# Int64Index([   37,    42,    52,    67,    68,    73,    85,    88,    89,
#                92,
#             ...
#             10647, 10679, 10681, 10707, 10712, 10713, 10725, 10765, 10826,
#             10839],
#            dtype='int64', length=1526)

# %%
data.drop(Varies_with_device,inplace=True)

# %%
data['Size'].convert_dtypes()
# Out:
# 0         19000000
# 1         14000000
# 2        8.7000000
# 3         25000000
# 4        2.8000000
#            ...
# 10835    9.6000000
# 10836     53000000
# 10837    3.6000000
# 10838    9.5000000
# 10840     19000000
# Name: Size, Length: 8831, dtype: string

# %%
#10. Check the column 'Installs', treat the unwanted characters and convert the column into a suitable data type.

# %%
data['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000+', '500,000,000+', '50+', '100+', '500+', '10+', '1+', '5+',
#        '1,000,000,000+', '0+'], dtype=object)

# %%
data['Installs'] = data['Installs'].apply(lambda x:x.replace('+',''))
data['Installs'] = data['Installs'].apply(lambda x:x.replace(',',''))
data['Installs'] = data['Installs'].apply(lambda x:int(x))

# %%
data['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#              1000,  500000000,         50,        100,        500,
#                10,          1,          5, 1000000000,          0])

# %%
data['Installs'].convert_dtypes
# Out:
# <bound method NDFrame.convert_dtypes of 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10835          10
# 10836        5000
# 10837         100
# 10838        1000
# 10840    10000000
# Name: Installs, Length: 8831, dtype: int64>

# %%
data.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size                object
# Installs             int64
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
#11. Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type.

# %%
data['Price'].unique()
# Out:
# array(['0', '$4.99', '$6.99', '$1.49', '$2.99', '$3.99', '$7.99', '$5.99',
#        '$1.99', '$9.99', '$0.99', '$9.00', '$5.49', '$10.00', '$24.99',
#        '$11.99', '$79.99', '$16.99', '$14.99', '$1.00', '$29.99',
#        '$12.99', '$3.49', '$10.99', '$7.49', '$1.50', '$19.99', '$15.99',
#        '$33.99', '$74.99', '$39.99', '$2.49', '$4.49', '$1.70', '$2.00',
#        '$3.88', '$25.99', '$399.99', '$17.99', '$400.00', '$3.02',
#        '$1.76', '$4.84', '$4.77', '$1.61', '$1.59', '$6.49', '$1.29',
#        '$5.00', '$13.99', '$299.99', '$379.99', '$37.99', '$18.99',
#        '$389.99', '$19.90', '$8.49', '$1.75', '$14.00', '$4.85', '$46.99',
#        '$109.99', '$154.99', '$3.08', '$2.59', '$4.80', '$8.99', '$1.96',
#        '$19.40', '$15.46', '$3.04', '$4.29', '$2.60', '$3.28', '$4.60',
#        '$28.99', '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99',
#        '$3.61', '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
data['Price'] = data['Price'].apply(lambda x:x.replace('$',''))

# %%
data['Price'] = data['Price'].apply(lambda x:x.replace(',',''))

# %%
data['Price'] = data['Price'].apply(lambda x:float(x))

# %%
data['Price'].unique()
# Out:
# array([  0.  ,   4.99,   6.99,   1.49,   2.99,   3.99,   7.99,   5.99,
#          1.99,   9.99,   0.99,   9.  ,   5.49,  10.  ,  24.99,  11.99,
#         79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,   3.49,  10.99,
#          7.49,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,   2.49,
#          4.49,   1.7 ,   2.  ,   3.88,  25.99, 399.99,  17.99, 400.  ,
#          3.02,   1.76,   4.84,   4.77,   1.61,   1.59,   6.49,   1.29,
#          5.  ,  13.99, 299.99, 379.99,  37.99,  18.99, 389.99,  19.9 ,
#          8.49,   1.75,  14.  ,   4.85,  46.99, 109.99, 154.99,   3.08,
#          2.59,   4.8 ,   8.99,   1.96,  19.4 ,  15.46,   3.04,   4.29,
#          2.6 ,   3.28,   4.6 ,  28.99,   2.9 ,   1.97, 200.  ,  89.99,
#          2.56,  30.99,   3.61, 394.99,   1.26,   1.2 ,   1.04])

# %%
data.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size                object
# Installs             int64
# Type                object
# Price              float64
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
#12. Drop the columns which you think redundant for the analysis.(suggestion: drop column 'rating', since we created a new feature from it (i.e. rating_category) and the columns 'App', 'Rating' ,'Genres','Last Updated', 'Current Ver','Android Ver' columns since which are redundant for our analysis)

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Rating_category'],
#       dtype='object')

# %%
data.drop(['App','Rating','Genres','Last Updated','Current Ver','Android Ver'],axis = 1,inplace = True)

# %%
data
# Out:
#              Category  Reviews       Size  Installs  Type  Price  \
# 0      ART_AND_DESIGN      159   19000000     10000  Free    0.0
# 1      ART_AND_DESIGN      967   14000000    500000  Free    0.0
# 2      ART_AND_DESIGN    87510  8.7000000   5000000  Free    0.0
# 3      ART_AND_DESIGN   215644   25000000  50000000  Free    0.0
# 4      ART_AND_DESIGN      967  2.8000000    100000  Free    0.0
# ...               ...      ...        ...       ...   ...    ...
# 10835        BUSINESS        0  9.6000000        10  Free    0.0
# 10836          FAMILY       38   53000000      5000  Free    0.0
# 10837          FAMILY        4  3.6000000       100  Free    0.0
# 10838         MEDICAL        3  9.5000000      1000  Free    0.0
# 10840       LIFESTYLE   398307   19000000  10000000  Free    0.0
#
#       Content Rating Rating_category
# 0           Everyone            high
# 1           Everyone            high
# 2           Everyone            high
# 3               Teen            high
# 4           Everyone            high
# ...              ...             ...
# 10835       Everyone            high
# 10836       Everyone            high
# 10837       Everyone            high
# 10838       Everyone            high
# 10840       Everyone            high
#
# [8831 rows x 8 columns]

# %%
#13.Encode the categorical columns

# %% [markdown]
# 1.Category

# %%
data['Category'].nunique()
# Out:
# 33

# %%
categories=list(data['Category'].unique())

# %%
categories
# Out:
# ['ART_AND_DESIGN',
#  'AUTO_AND_VEHICLES',
#  'BEAUTY',
#  'BOOKS_AND_REFERENCE',
#  'BUSINESS',
#  'COMICS',
#  'COMMUNICATION',
#  'DATING',
#  'EDUCATION',
#  'ENTERTAINMENT',
#  'EVENTS',
#  'FINANCE',
#  'FOOD_AND_DRINK',
#  'HEALTH_AND_FITNESS',
#  'HOUSE_AND_HOME',
#  'LIBRARIES_AND_DEMO',
#  'LIFESTYLE',
#  'GAME',
#  'FAMILY',
#  'MEDICAL',
#  'SOCIAL',
#  'SHOPPING',
#  'PHOTOGRAPHY',
#  'SPORTS',
#  'TRAVEL_AND_LOCAL',
#  'TOOLS',
#  'PERSONALIZATION',
#  'PRODUCTIVITY',
#  'PARENTING',
#  'WEATHER',
#  'VIDEO_PLAYERS',
#  'NEWS_AND_MAGAZINES',
#  'MAPS_AND_NAVIGATION']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
data['Category']=encoder.fit_transform(data['Category'])

# %%
data
# Out:
#        Category  Reviews       Size  Installs  Type  Price Content Rating  \
# 0             0      159   19000000     10000  Free    0.0       Everyone
# 1             0      967   14000000    500000  Free    0.0       Everyone
# 2             0    87510  8.7000000   5000000  Free    0.0       Everyone
# 3             0   215644   25000000  50000000  Free    0.0           Teen
# 4             0      967  2.8000000    100000  Free    0.0       Everyone
# ...         ...      ...        ...       ...   ...    ...            ...
# 10835         4        0  9.6000000        10  Free    0.0       Everyone
# 10836        11       38   53000000      5000  Free    0.0       Everyone
# 10837        11        4  3.6000000       100  Free    0.0       Everyone
# 10838        20        3  9.5000000      1000  Free    0.0       Everyone
# 10840        18   398307   19000000  10000000  Free    0.0       Everyone
#
#       Rating_category
# 0                high
# 1                high
# 2                high
# 3                high
# 4                high
# ...               ...
# 10835            high
# 10836            high
# 10837            high
# 10838            high
# 10840            high
#
# [8831 rows x 8 columns]

# %%
data['Category'].value_counts()
# Out:
# 11    1806
# 14    1000
# 29     739
# 20     380
# 4      379
# 23     354
# 18     338
# 12     304
# 25     299
# 28     296
# 6      260
# 24     243
# 15     240
# 21     209
# 27     203
# 3      196
# 26     181
# 30     179
# 7      178
# 31     131
# 19     108
# 13      98
# 8       96
# 17      82
# 1       75
# 9       67
# 16      62
# 0       62
# 10      57
# 32      57
# 22      54
# 5       51
# 2       47
# Name: Category, dtype: int64

# %% [markdown]
# 2.Content Rating

# %%
content=list(data['Content Rating'].unique())

# %%
content
# Out:
# ['Everyone',
#  'Teen',
#  'Everyone 10+',
#  'Mature 17+',
#  'Adults only 18+',
#  'Unrated']

# %%
encoder=LabelEncoder()

# %%
data['Content Rating']=encoder.fit_transform(data['Content Rating'])

# %%
data
# Out:
#        Category  Reviews       Size  Installs  Type  Price  Content Rating  \
# 0             0      159   19000000     10000  Free    0.0               1
# 1             0      967   14000000    500000  Free    0.0               1
# 2             0    87510  8.7000000   5000000  Free    0.0               1
# 3             0   215644   25000000  50000000  Free    0.0               4
# 4             0      967  2.8000000    100000  Free    0.0               1
# ...         ...      ...        ...       ...   ...    ...             ...
# 10835         4        0  9.6000000        10  Free    0.0               1
# 10836        11       38   53000000      5000  Free    0.0               1
# 10837        11        4  3.6000000       100  Free    0.0               1
# 10838        20        3  9.5000000      1000  Free    0.0               1
# 10840        18   398307   19000000  10000000  Free    0.0               1
#
#       Rating_category
# 0                high
# 1                high
# 2                high
# 3                high
# 4                high
# ...               ...
# 10835            high
# 10836            high
# 10837            high
# 10838            high
# 10840            high
#
# [8831 rows x 8 columns]

# %%
data['Content Rating'].value_counts()
# Out:
# 1    7195
# 4     951
# 3     368
# 2     313
# 0       2
# 5       2
# Name: Content Rating, dtype: int64

# %% [markdown]
# 3.Type

# %%
data['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
data['Type'] = encoder.fit_transform(data['Type'])

# %%
data['Type'].value_counts()
# Out:
# 0    8140
# 1     691
# Name: Type, dtype: int64

# %%
data
# Out:
#        Category  Reviews       Size  Installs  Type  Price  Content Rating  \
# 0             0      159   19000000     10000     0    0.0               1
# 1             0      967   14000000    500000     0    0.0               1
# 2             0    87510  8.7000000   5000000     0    0.0               1
# 3             0   215644   25000000  50000000     0    0.0               4
# 4             0      967  2.8000000    100000     0    0.0               1
# ...         ...      ...        ...       ...   ...    ...             ...
# 10835         4        0  9.6000000        10     0    0.0               1
# 10836        11       38   53000000      5000     0    0.0               1
# 10837        11        4  3.6000000       100     0    0.0               1
# 10838        20        3  9.5000000      1000     0    0.0               1
# 10840        18   398307   19000000  10000000     0    0.0               1
#
#       Rating_category
# 0                high
# 1                high
# 2                high
# 3                high
# 4                high
# ...               ...
# 10835            high
# 10836            high
# 10837            high
# 10838            high
# 10840            high
#
# [8831 rows x 8 columns]

# %% [markdown]
# 4.Rating_category

# %%
data['Rating_category'].unique()
# Out:
# array(['high', 'low'], dtype=object)

# %%
data['Rating_category'] = encoder.fit_transform(data['Rating_category'])

# %%
data['Rating_category'].value_counts()
# Out:
# 0    8006
# 1     825
# Name: Rating_category, dtype: int64

# %%
data
# Out:
#        Category  Reviews       Size  Installs  Type  Price  Content Rating  \
# 0             0      159   19000000     10000     0    0.0               1
# 1             0      967   14000000    500000     0    0.0               1
# 2             0    87510  8.7000000   5000000     0    0.0               1
# 3             0   215644   25000000  50000000     0    0.0               4
# 4             0      967  2.8000000    100000     0    0.0               1
# ...         ...      ...        ...       ...   ...    ...             ...
# 10835         4        0  9.6000000        10     0    0.0               1
# 10836        11       38   53000000      5000     0    0.0               1
# 10837        11        4  3.6000000       100     0    0.0               1
# 10838        20        3  9.5000000      1000     0    0.0               1
# 10840        18   398307   19000000  10000000     0    0.0               1
#
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10835                0
# 10836                0
# 10837                0
# 10838                0
# 10840                0
#
# [8831 rows x 8 columns]

# %%
#14. Segregate the target and independent features (Hint: Use Rating_category as the target)

# %%
x=data.drop('Rating_category',axis=1)

# %%
y=data[['Rating_category']]

# %%
x
# Out:
#        Category  Reviews       Size  Installs  Type  Price  Content Rating
# 0             0      159   19000000     10000     0    0.0               1
# 1             0      967   14000000    500000     0    0.0               1
# 2             0    87510  8.7000000   5000000     0    0.0               1
# 3             0   215644   25000000  50000000     0    0.0               4
# 4             0      967  2.8000000    100000     0    0.0               1
# ...         ...      ...        ...       ...   ...    ...             ...
# 10835         4        0  9.6000000        10     0    0.0               1
# 10836        11       38   53000000      5000     0    0.0               1
# 10837        11        4  3.6000000       100     0    0.0               1
# 10838        20        3  9.5000000      1000     0    0.0               1
# 10840        18   398307   19000000  10000000     0    0.0               1
#
# [8831 rows x 7 columns]

# %%
y
# Out:
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10835                0
# 10836                0
# 10837                0
# 10838                0
# 10840                0
#
# [8831 rows x 1 columns]

# %%
#15. Split the dataset into train and test.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=100)

# %%
x_train
# Out:
#       Category  Reviews       Size  Installs  Type  Price  Content Rating
# 8385        26        2  1.3000000       100     0    0.0               1
# 1931        14   401425   70000000  10000000     0    0.0               1
# 377          6    40751   35000000  10000000     0    0.0               4
# 6701         4       30   93000000       100     0    0.0               2
# 4678        14     2113   67000000    100000     0    0.0               2
# ...        ...      ...        ...       ...   ...    ...             ...
# 523          7     1972   13000000   1000000     0    0.0               3
# 86           1      348   38000000    100000     0    0.0               1
# 9995        12        1   29000000       100     0    0.0               1
# 8790        11      267  1.5000000     10000     0    0.0               1
# 7392        11      101  5.1000000      1000     0    0.0               1
#
# [6623 rows x 7 columns]

# %%
x_test
# Out:
#        Category  Reviews       Size   Installs  Type  Price  Content Rating
# 2096         11   106750   94000000    1000000     0   0.00               1
# 3133         30     2277   27000000    1000000     0   0.00               1
# 10256        21        2  3.6000000        500     0   0.00               1
# 1471         16      114  8.3000000      10000     0   0.00               4
# 8842          4        2  1.4000000         10     0   0.00               1
# ...         ...      ...        ...        ...   ...    ...             ...
# 2433         20        0   29000000         10     0   0.00               1
# 7619         14     3904  5.5000000      10000     1   2.99               2
# 1030         10       16  2.3000000        100     0   0.00               1
# 2016         11  4449910   67000000  100000000     0   0.00               2
# 7093         18       74  2.9000000       5000     0   0.00               4
#
# [2208 rows x 7 columns]

# %%
y_train
# Out:
#       Rating_category
# 8385                1
# 1931                0
# 377                 0
# 6701                0
# 4678                0
# ...               ...
# 523                 1
# 86                  0
# 9995                0
# 8790                1
# 7392                0
#
# [6623 rows x 1 columns]

# %%
y_test
# Out:
#        Rating_category
# 2096                 0
# 3133                 1
# 10256                0
# 1471                 0
# 8842                 0
# ...                ...
# 2433                 0
# 7619                 0
# 1030                 0
# 2016                 0
# 7093                 0
#
# [2208 rows x 1 columns]

# %%
#16. Standardize the data, so that the values are within a particular range.

# %%
from sklearn.preprocessing import StandardScaler

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8831 entries, 0 to 10840
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Category         8831 non-null   int64
#  1   Reviews          8831 non-null   int64
#  2   Size             8831 non-null   object
#  3   Installs         8831 non-null   int64
#  4   Type             8831 non-null   int64
#  5   Price            8831 non-null   float64
#  6   Content Rating   8831 non-null   int64
#  7   Rating_category  8831 non-null   int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 620.9+ KB

# %%
scaler = StandardScaler()

# %%
data= scaler.fit_transform(data)

# %%
data=pd.DataFrame(data)

# %%
data
# Out:
#              0         1         2         3         4         5         6  \
# 0    -2.001200 -0.146208 -0.013341 -0.154361 -0.291358 -0.066713 -0.447175
# 1    -2.001200 -0.145704 -0.221692 -0.142844 -0.291358 -0.066713 -0.447175
# 2    -2.001200 -0.091677 -0.805072 -0.037084 -0.291358 -0.066713 -0.447175
# 3    -2.001200 -0.011685  0.236679  1.020521 -0.291358 -0.066713  2.584298
# 4    -2.001200 -0.145704 -0.805073 -0.152245 -0.291358 -0.066713 -0.447175
# ...        ...       ...       ...       ...       ...       ...       ...
# 8826 -1.516926 -0.146307 -0.805072 -0.154595 -0.291358 -0.066713 -0.447175
# 8827 -0.669447 -0.146284  1.403441 -0.154478 -0.291358 -0.066713 -0.447175
# 8828 -0.669447 -0.146305 -0.805073 -0.154593 -0.291358 -0.066713 -0.447175
# 8829  0.420168 -0.146306 -0.805072 -0.154572 -0.291358 -0.066713 -0.447175
# 8830  0.178031  0.102348 -0.013341  0.080428 -0.291358 -0.066713 -0.447175
#
#             7
# 0    -0.32101
# 1    -0.32101
# 2    -0.32101
# 3    -0.32101
# 4    -0.32101
# ...       ...
# 8826 -0.32101
# 8827 -0.32101
# 8828 -0.32101
# 8829 -0.32101
# 8830 -0.32101
#
# [8831 rows x 8 columns]
